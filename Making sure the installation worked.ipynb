# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0 , 10 , 1000)
y = np.zeros(1000)

for i in range(1000):
    y[i] = -x[i]**3 + 14*x[i]**2 + 3

# %%
plt.plot(x , y , 'r-')
plt.grid(True)
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')
